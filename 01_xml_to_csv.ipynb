# %%
import pandas as pd
import xml.etree.ElementTree as xet

# %%
import glob

# %%
path = glob.glob('./image/*.xml')
path_sort = sorted(path)
path_sort
# Out:
# ['./image/N1.xml',
#  './image/N100.xml',
#  './image/N101.xml',
#  './image/N102.xml',
#  './image/N103.xml',
#  './image/N104.xml',
#  './image/N105.xml',
#  './image/N106.xml',
#  './image/N107.xml',
#  './image/N108.xml',
#  './image/N109.xml',
#  './image/N11.xml',
#  './image/N110.xml',
#  './image/N111.xml',
#  './image/N112.xml',
#  './image/N113.xml',
#  './image/N114.xml',
#  './image/N116.xml',
#  './image/N117.xml',
#  './image/N118.xml',
#  './image/N119.xml',
#  './image/N12.xml',
#  './image/N120.xml',
#  './image/N121.xml',
#  './image/N122.xml',
#  './image/N123.xml',
#  './image/N124.xml',
#  './image/N126.xml',
#  './image/N127.xml',
#  './image/N128.xml',
#  './image/N129.xml',
#  './image/N130.xml',
#  './image/N131.xml',
#  './image/N132.xml',
#  './image/N133.xml',
#  './image/N134.xml',
#  './image/N135.xml',
#  './image/N136.xml',
#  './image/N137.xml',
#  './image/N138.xml',
#  './image/N139.xml',
#  './image/N14.xml',
#  './image/N140.xml',
#  './image/N141.xml',
#  './image/N142.xml',
#  './image/N143.xml',
#  './image/N144.xml',
#  './image/N145.xml',
#  './image/N147.xml',
#  './image/N148.xml',
#  './image/N149.xml',
#  './image/N15.xml',
#  './image/N150.xml',
#  './image/N151.xml',
#  './image/N152.xml',
#  './image/N153.xml',
#  './image/N154.xml',
#  './image/N155.xml',
#  './image/N156.xml',
#  './image/N158.xml',
#  './image/N16.xml',
#  './image/N160.xml',
#  './image/N162.xml',
#  './image/N163.xml',
#  './image/N164.xml',
#  './image/N165.xml',
#  './image/N166.xml',
#  './image/N167.xml',
#  './image/N168.xml',
#  './image/N169.xml',
#  './image/N17.xml',
#  './image/N170.xml',
#  './image/N171.xml',
#  './image/N172.xml',
#  './image/N173.xml',
#  './image/N174.xml',
#  './image/N175.xml',
#  './image/N176.xml',
#  './image/N177.xml',
#  './image/N178.xml',
#  './image/N179.xml',
#  './image/N18.xml',
#  './image/N180.xml',
#  './image/N182.xml',
#  './image/N183.xml',
#  './image/N184.xml',
#  './image/N185.xml',
#  './image/N186.xml',
#  './image/N187.xml',
#  './image/N188.xml',
#  './image/N189.xml',
#  './image/N19.xml',
#  './image/N190.xml',
#  './image/N191.xml',
#  './image/N192.xml',
#  './image/N193.xml',
#  './image/N195.xml',
#  './image/N196.xml',
#  './image/N197.xml',
#  './image/N198.xml',
#  './image/N199.xml',
#  './image/N2.xml',
#  './image/N20.xml',
#  './image/N200.xml',
#  './image/N201.xml',
#  './image/N202.xml',
#  './image/N203.xml',
#  './image/N204.xml',
#  './image/N205.xml',
#  './image/N206.xml',
#  './image/N207.xml',
#  './image/N208.xml',
#  './image/N209.xml',
#  './image/N21.xml',
#  './image/N210.xml',
#  './image/N211.xml',
#  './image/N212.xml',
#  './image/N213.xml',
#  './image/N214.xml',
#  './image/N215.xml',
#  './image/N216.xml',
#  './image/N217.xml',
#  './image/N218.xml',
#  './image/N219.xml',
#  './image/N22.xml',
#  './image/N220.xml',
#  './image/N221.xml',
#  './image/N222.xml',
#  './image/N223.xml',
#  './image/N224.xml',
#  './image/N225.xml',
#  './image/N226.xml',
#  './image/N227.xml',
#  './image/N229.xml',
#  './image/N23.xml',
#  './image/N230.xml',
#  './image/N231.xml',
#  './image/N232.xml',
#  './image/N233.xml',
#  './image/N234.xml',
#  './image/N235.xml',
#  './image/N236.xml',
#  './image/N237.xml',
#  './image/N238.xml',
#  './image/N239.xml',
#  './image/N24.xml',
#  './image/N240.xml',
#  './image/N241.xml',
#  './image/N242.xml',
#  './image/N244.xml',
#  './image/N245.xml',
#  './image/N246.xml',
#  './image/N247.xml',
#  './image/N248.xml',
#  './image/N249.xml',
#  './image/N25.xml',
#  './image/N250.xml',
#  './image/N27.xml',
#  './image/N28.xml',
#  './image/N3.xml',
#  './image/N30.xml',
#  './image/N31.xml',
#  './image/N32.xml',
#  './image/N33.xml',
#  './image/N34.xml',
#  './image/N35.xml',
#  './image/N36.xml',
#  './image/N37.xml',
#  './image/N38.xml',
#  './image/N4.xml',
#  './image/N40.xml',
#  './image/N42.xml',
#  './image/N43.xml',
#  './image/N44.xml',
#  './image/N45.xml',
#  './image/N46.xml',
#  './image/N47.xml',
#  './image/N48.xml',
#  './image/N49.xml',
#  './image/N5.xml',
#  './image/N50.xml',
#  './image/N51.xml',
#  './image/N52.xml',
#  './image/N53.xml',
#  './image/N54.xml',
#  './image/N56.xml',
#  './image/N57.xml',
#  './image/N58.xml',
#  './image/N59.xml',
#  './image/N6.xml',
#  './image/N61.xml',
#  './image/N62.xml',
#  './image/N63.xml',
#  './image/N64.xml',
#  './image/N65.xml',
#  './image/N66.xml',
#  './image/N67.xml',
#  './image/N68.xml',
#  './image/N69.xml',
#  './image/N7.xml',
#  './image/N70.xml',
#  './image/N72.xml',
#  './image/N73.xml',
#  './image/N74.xml',
#  './image/N75.xml',
#  './image/N77.xml',
#  './image/N78.xml',
#  './image/N79.xml',
#  './image/N8.xml',
#  './image/N80.xml',
#  './image/N81.xml',
#  './image/N82.xml',
#  './image/N84.xml',
#  './image/N85.xml',
#  './image/N86.xml',
#  './image/N88.xml',
#  './image/N89.xml',
#  './image/N9.xml',
#  './image/N90.xml',
#  './image/N91.xml',
#  './image/N92.xml',
#  './image/N93.xml',
#  './image/N94.xml',
#  './image/N95.xml',
#  './image/N96.xml',
#  './image/N97.xml',
#  './image/N98.xml',
#  './image/N99.xml']

# %%
labels_dict = dict(filepath=[],xmin=[],xmax=[],ymin=[],ymax=[])
for filename in path_sort:

    #filename = path[0]
    info = xet.parse(filename)
    root = info.getroot()
    member_object = root.find('object')
    labels_info = member_object.find('bndbox')
    xmin = int(labels_info.find('xmin').text)
    xmax = int(labels_info.find('xmax').text)
    ymin = int(labels_info.find('ymin').text)
    ymax = int(labels_info.find('ymax').text)
    
    #print(xmin,xmax,ymin,ymax)
    labels_dict['filepath'].append(filename)
    labels_dict['xmin'].append(xmin)
    labels_dict['xmax'].append(xmax)
    labels_dict['ymin'].append(ymin)
    labels_dict['ymax'].append(ymax)

# %%
df = pd.DataFrame(labels_dict)
df
# Out:
#              filepath  xmin  xmax  ymin  ymax
# 0      ./image/N1.xml  1100  1391   669   706
# 1    ./image/N100.xml   138   297   316   343
# 2    ./image/N101.xml    33   135   132   157
# 3    ./image/N102.xml   164   316   221   245
# 4    ./image/N103.xml   819  1064   685   734
# ..                ...   ...   ...   ...   ...
# 223   ./image/N95.xml    23   395   249   405
# 224   ./image/N96.xml   148   344   152   186
# 225   ./image/N97.xml   192   279   231   254
# 226   ./image/N98.xml   567   670   211   234
# 227   ./image/N99.xml   159   382   140   182
#
# [228 rows x 5 columns]

# %%
df.to_csv('labels.csv',index=False)
